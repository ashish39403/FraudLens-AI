# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
load_dotenv()
# Out:
# True

# %%
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langfuse.langchain import CallbackHandler

load_dotenv()

llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_BASE_URL"),
)

# Langfuse callback
langfuse_handler = CallbackHandler()

q = "what is gen ai? then tell me what is ML and what is agentic ai and  prepare a report acc on them"

result = llm.invoke(
    q,
    config={
        "callbacks": [langfuse_handler]
    }
)

print(result.content)
# Out:
# # Report on Generative AI, Machine Learning, and Agentic AI
#
# ## 1. Introduction
#
# In recent years, the fields of artificial intelligence (AI) and machine learning (ML) have seen significant advancements, leading to the development of innovative technologies and applications. This report provides an overview of three key concepts: Generative AI, Machine Learning, and Agentic AI. Each concept is defined, explained, and contextualized within the broader landscape of AI.
#
# ## 2. Generative AI
#
# ### Definition
# Generative AI refers to a subset of artificial intelligence that generates new content, data, or information by leveraging existing data patterns. Unlike traditional AI models, which may classify or process input data, generative AI creates new instances that resemble the training data.
#
# ### Examples
# 1. **Text Generation**: Models like OpenAI's GPT-3 and GPT-4 can generate coherent and contextually relevant text based on prompts.
# 2. **Image Generation**: Tools like DALL-E and Midjourney create images from textual descriptions.
# 3. **Music Composition**: AI models can compose original music based on learned styles.
#
# ### Applications
# - Content creation for marketing and entertainment.
# - Automated customer service responses.
# - Drug discovery in pharmaceuticals by simulating molecular structures.
#
# ### Implications
# Generative AI raises questions regarding copyright, creativity, and the authenticity of generated content. The ability to create hyper-realistic deepfakes also necessitates discussions on ethics and security.
#
# ## 3. Machine Learning
#
# ### Definition
# Machine Learning (ML) is a branch of artificial intelligence that focuses on the development of algorithms that allow computers to learn from and make predictions or decisions based on data. ML models improve their performance as they are exposed to more data over time.
#
# ### Types of Machine Learning
# 1. **Supervised Learning**: The model learns from labeled data, using examples with known outputs. Common applications include regression and classification tasks.
# 2. **Unsupervised Learning**: The model seeks patterns in data without predefined labels. Clustering and dimensionality reduction are typical examples.
# 3. **Reinforcement Learning**: An agent learns to make decisions by receiving rewards or penalties based on its actions in a given environment.
#
# ### Applications
# - Recommendation systems (e.g., Netflix, Amazon).
# - Fraud detection in finance.
# - Image and speech recognition.
#
# ### Implications
# ML has transformed various industries by enabling data-driven decision-making. However, challenges related to algorithmic bias, transparency, and data privacy persist.
#
# ## 4. Agentic AI
#
# ### Definition
# Agentic AI refers to AI systems that possess a degree of autonomy and can act on behalf of users or stakeholders to achieve specific goals. This type of AI is designed to perform tasks with a level of decision-making capability, often requiring an understanding of context and user preferences.
#
# ### Characteristics
# - **Autonomy**: The ability to operate independently without explicit human intervention.
# - **Goal-oriented behavior**: The capability to pursue objectives based on external or internal motivations.
# - **Adaptability**: The ability to learn from interactions and adjust strategies accordingly.
#
# ### Examples
# 1. **Personal Assistants**: Virtual assistants like Siri or Google Assistant can perform tasks based on user commands.
# 2. **Smart Agents in Gaming**: Characters in video games that learn and adapt to players' strategies to provide a challenging experience.
# 3. **Automated Trading Systems**: Financial systems that execute trades based on market analysis and user settings.
#
# ### Applications
# - Personal assistance and home automation.
# - Autonomous vehicles capable of navigating and making decisions in real-time.
# - Intelligent robotics for manufacturing and service industries.
#
# ### Implications
# Agentic AI raises questions about trust, accountability, and the ethical implications of delegating decision-making to automated systems. Additionally, there are concerns about job displacement and the need for new frameworks to govern the behavior of such systems.
#
# ## 5. Conclusion
#
# Generative AI, Machine Learning, and Agentic AI represent powerful advancements in artificial intelligence. Each serves distinct purposes but also overlaps in many applications and capabilities. As these technologies continue to evolve, it is critical to address the ethical, societal, and legal implications associated with their use. Understanding these concepts will prepare stakeholders—including developers, businesses, and policymakers—to navigate the challenges and opportunities presented by AI in the coming years.
